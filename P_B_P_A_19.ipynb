# %% [markdown]
# ## Q1

# %%
# Create a function that takes a string and returns a string in which each character is repeated
# once.

def double_char(string):
    nstring = ""
    for i in string:
        nstring = nstring+i+i
    
    return nstring 

double_char("String")
# Out:
# 'SSttrriinngg'

# %% [markdown]
# ## Q2

# %%
# Create a function that reverses a boolean value and returns the string &quot;boolean expected&quot;
# if another variable type is given.

def reverse(bool_val):
    if(isinstance(bool_val,bool)==True):
        if(bool(bool_val)==True):
            return False
        else: return True

    else: 
         return "boolean expected"
    
reverse(True)
# Out:
# False

# %%
reverse(None)
# Out:
# 'boolean expected'

# %% [markdown]
# ## Q3

# %%
# Create a function that returns the thickness (in meters) of a piece of paper after folding it n
# number of times. The paper starts off with a thickness of 0.5mm.

def num_layers(l):
    thick = 0.5
    for i in range(0,l):
        thick*= 2
    print("Paper folded {} times is {:.0f}mm (equal to {}m)".format(l,thick,thick/1000))
    
num_layers(21)
# Out:
# Paper folded 21 times is 1048576mm (equal to 1048.576m)

# %% [markdown]
# ## Q4

# %%
# Create a function that takes a single string as argument and returns an ordered list containing
# the indices of all capital letters in the string.

def index_of_caps(string):
    l=[]
    for i in range(0,len(string)):
        if(string[i].isupper()==True):
            l.append(i)
    
    l.sort()
    return l

index_of_caps("eDaBiT")
# Out:
# [1, 3, 5]

# %%
index_of_caps("determine")
# Out:
# []

# %% [markdown]
# ## Q5

# %%
# Using list comprehensions, create a function that finds all even numbers from 1 to the given
# number.

def find_even_nums(val):
    l = [i for i in range(1,val + 1) if i%2==0]
    return l

find_even_nums(8)
# Out:
# [2, 4, 6, 8]

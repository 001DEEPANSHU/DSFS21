# %% [markdown]
# ## Q1

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# ## Q2

# %%
x=4
y=5
s = x+y
d = x/y
print("The sum of x and y is : ",s)
print("The quotient of x and y is : ",d)
# Out:
# The sum of x and y is :  9
# The quotient of x and y is :  0.8

# %% [markdown]
# ## Q3

# %%
 s1 = float(input('Enter first side of the triangle: '))
 s2 = float(input('Enter second side of the triangle: '))
 s3 = float(input('Enter third of the triangle: '))

s = (s1 + s2 + s3) / 2 #calculating semi-perimeter

area = (s*(s-s1)*(s-s2)*(s-s3)) ** 0.5 #calculating area

print('The area of the triangle is %0.4f' %area)
# Out:
# Enter first side of the triangle: 4
# Enter second side of the triangle: 5
# Enter third of the triangle: 8
# The area of the triangle is 8.1815

# %% [markdown]
# ## Q4

# %%
v1 = input('Enter the first variable: ')
v2 = input('Enter the second variable: ')
t = v1
v1 = v2
v2 = t 
print("The first variable after swapping is : ", v1)
print("The second variable after swapping is : ", v2)
# Out:
# Enter the first variable: 12
# Enter the second variable: 54
# The first variable after swapping is :  54
# The second variable after swapping is :  12

# %% [markdown]
# ## Q5

# %%
import random
l = int(input('Enter the lower bound value for the random number interval: '))
u = int(input('Enter the upper bound value for the random number interval: '))
rno=random.randint(l,u)

print("The random number generated from the interval ({0},{1}) is {2}".format(l,u,rno))
# Out:
# Enter the lower bound value for the random number interval: 10
# Enter the upper bound value for the random number interval: 30
# The random number generated from the interval (10,30) is 22

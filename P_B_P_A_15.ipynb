# %% [markdown]
# ## Q1

# %%
# Please write a program using generator to print the numbers which can be divisible by 5 and
# 7 between 0 and n in comma separated form while n is input by console.

def gen_class(n):
    for i in range(0,n+1):
        if(i%5==0 and i%7==0):
            yield i

n= int(input("Enter the value of n: "))
result = []
for i in gen_class(n):
    result.append(str(i))

    
print(",".join(result))
# Out:
# Enter the value of n: 100
# 0,35,70

# %% [markdown]
# # Q2

# %%
# Please write a program using generator to print the even numbers between 0 and n in comma
# separated form while n is input by console

def gen_class_even(n):
    for i in range(0,n+1):
        if(i%2==0):
            yield i

n= int(input("Enter the value of n: "))
result = []
for i in gen_class_even(n):
    result.append(str(i))

    
print(",".join(result))
# Out:
# Enter the value of n: 10
# 0,2,4,6,8,10

# %% [markdown]
# ## Q3

# %%
# Please write a program using list comprehension to print the Fibonacci Sequence in comma
# separated form with a given n input by console

n = int(input("\nEnter the value of n: "))

series = [0,1]

def fib_ser(n):
    a = 0 
    b = 1 
    if(n==0):
        print([a])
    elif(n==1):
        print([a,b])
    else:
        for i in range(2,n+1):
            series.append(series[i-1]+series[i-2])
            a = series[i-1]
            b = series[i]
    return series

fib_list = [str(i) for i in fib_ser(n)]
print(",".join(fib_list))
# Out:
# Enter the value of n: 7
# 0,1,1,2,3,5,8,13

# %% [markdown]
# ## Q4

# %%
import re
email = input("Enter the email address:")
pattern = "(\w+)@(\w+)\.(com)"
re_ob = re.match(pattern,email)
print(re_ob.group(1))
# Out:
# Enter the email address:john@google.com
# john

# %% [markdown]
# ## Q5

# %%
# Define a class named Shape and its subclass Square. The Square class has an init function
# which takes a length as argument. Both classes have a area function which can print the area
# of the shape where Shape's area is 0 by default


class Shape():
    def __init__(self):
        pass

    def area(self):
        return 0

class Square(Shape):
    def __init__(self,length = 0):
        #Shape.__init__(self)
        self.length = length

    def area(self):
        return self.length*self.length

n = int(input("Enter value of side of the square: "))
sq = Square(n)
sq.area()
# Out:
# Enter value of side of the square: 13
# 169
